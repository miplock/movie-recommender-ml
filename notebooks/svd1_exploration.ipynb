# %%
import sys
import os

# ścieżka do folderu głównego projektu
project_root = os.path.abspath("..")
sys.path.append(project_root)

print(project_root)
# Out:
# /mnt/windows/Users/mikołaj/Desktop/dokumenty/studia/2025-2026L/mocadr/laby/project_1/project1_s324671

# %%
from modules.models.svd1_model import SVD1Recommender

# %%
train_path = "../data/ratings.csv"
model_path = "../models_trained/test_svd1_model.pkl"

# %%
import pickle

with open("../results/nmf_rmse_runs.pkl", "rb") as f:
    data = pickle.load(f)

rmse_list = [run["rmse"] for run in data["runs"]]
rmse_list
# Out:
# [0.8648422516705027,
#  0.8654669741951955,
#  0.8637148901576417,
#  0.8627656760934431,
#  0.8662157602731727,
#  0.8648035498863709,
#  0.865704708769859,
#  0.8665033625289572,
#  0.8639186699482401,
#  0.8648393849310716]
